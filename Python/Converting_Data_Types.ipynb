# %% [markdown]
# # Converting Data Types

# %%
num_int = 7
type(num_int)
# Out:
# int

# %%
num_str = '7'
type(num_str)
# Out:
# str

# %%
num_str_conv = int(num_str)

type(num_str_conv)
# Out:
# int

# %%
num_sum = num_int + num_str_conv

print(num_sum)
# Out:
# 14

# %%
type(num_sum)
# Out:
# int

# %%
list_type = [1,2,3]

type(list_type)
# Out:
# list

# %%
tuple(list_type)
# Out:
# (1, 2, 3)

# %%
type(tuple(list_type))
# Out:
# tuple

# %%
list_type = [1,2,3,3,2,1,3,4,5,3,1]

# %%
type(set(list_type))
# Out:
# set

# %%
dict_type = {'name': 'Christopher Wijk Karlsson', 'Age': 35, 'Hair': 'Lightbrown'}
type(dict_type)
# Out:
# dict

# %%
dict_type.items()
# Out:
# dict_items([('name', 'Christopher Wijk Karlsson'), ('Age', 35), ('Hair', 'Lightbrown')])

# %%
dict_type.values()
# Out:
# dict_values(['Christopher Wijk Karlsson', 35, 'Lightbrown'])

# %%
dict_type.keys()
# Out:
# dict_keys(['name', 'Age', 'Hair'])

# %%
dict_type.values()
# Out:
# ['name', 'Age', 'Hair']

# %%
type(list(dict_type.keys()))
# Out:
# list

# %%
type(list(dict_type.values()))
# Out:
# list

# %%
long_str = 'I like to travel'

list(long_str)
# Out:
# ['I',
#  ' ',
#  'l',
#  'i',
#  'k',
#  'e',
#  ' ',
#  't',
#  'o',
#  ' ',
#  't',
#  'r',
#  'a',
#  'v',
#  'e',
#  'l']

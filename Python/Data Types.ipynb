# %%
type(-12+100)
# Out:
# int

# %%
type(12+10.25)
# Out:
# float

# %%
type(12+3j)
# Out:
# complex

# %%
#Boolean
type(1 > 5)
# Out:
# bool

# %%
1 > 5
# Out:
# False

# %%
1 == 1
# Out:
# True

# %%
# Strings
'Single Quote'
# Out:
# 'Single Quote'

# %%
"Double Quote"
# Out:
# 'Double Quote'

# %%
multiline = """
The ice cream vanquished
my longing for sweets,
upon this diet I look away,
it no longer exists on this day.
"""

# %%
print(multiline)
# Out:
# The ice cream vanquished
# my longing for sweets,
# upon this diet I look away,
# it no longer exists on this day.

# %%
"I've always wanted to eat a gallon of ice cream."
# Out:
# "I've always wanted to eat a gallon of ice cream."

# %%
a = 'Hello World!'

# %%
print(a[:5])
# Out:
# Hello

# %%
print(a[2:5])
# Out:
# llo

# %%
a*3
# Out:
# 'Hello World!Hello World!Hello World!'

# %%
a+a
# Out:
# 'Hello World!Hello World!'

# %%
# list

[1,2,3]
# Out:
# [1, 2, 3]

# %%
['Cookie Dough','Strawberry', 'Chocolate']
# Out:
# ['Cookie Dough', 'Strawberry', 'Chocolate']

# %%
['Vanilla', 3, ['Scoops', 'Spoon'], True]
# Out:
# ['Vanilla', 3, ['Scoops', 'Spoon'], True]

# %%
ice_cream = ['Cookie Dough','Strawberry', 'Chocolate']

ice_cream.append('Salted Caramel')

ice_cream
# Out:
# ['Cookie Dough', 'Strawberry', 'Chocolate', 'Salted Caramel']

# %%
ice_cream[0] = 'Butter Pecan'

ice_cream
# Out:
# ['Butter Pecan', 'Strawberry', 'Chocolate', 'Salted Caramel']

# %%
nested_list = ['Vanilla', 3, ['Scoops', 'Spoon'], True]

# %%
nested_list[2][1]
# Out:
# 'Spoon'

# %%
#tuple
# Good for static names that wont change like a city name.
tuple_scoops = (1,2,3,2,1)

# %%
type(tuple_scoops)
# Out:
# tuple

# %%
tuple_scoops[0]
# Out:
# 1

# %%
# sets

daily_pints = {1,2,3}

# %%
type(daily_pints)
# Out:
# set

# %%
print(daily_pints)
# Out:
# {1, 2, 3}

# %%
daily_pints_log = {1,2,31,2,3,4,1,2,5,6,3,2}
print(daily_pints_log)
# Out:
# {1, 2, 3, 4, 5, 6, 31}

# %%
wifes_daily_pints_log = {1,2,3,7,24,3,2,0}

# %%
print (daily_pints_log|wifes_daily_pints_log)
# Out:
# {0, 1, 2, 3, 4, 5, 6, 7, 24, 31}

# %%
print (daily_pints_log & wifes_daily_pints_log)
# Out:
# {1, 2, 3}

# %%
print (daily_pints_log - wifes_daily_pints_log)
# Out:
# {4, 5, 6, 31}

# %%
print (daily_pints_log ^ wifes_daily_pints_log)
# Out:
# {0, 4, 5, 6, 7, 24, 31}

# %%
# Dictionaries 
# key/value pair

dict_cream = {'name': 'Christopher Wijk', 'weekly intake': 5, 'favorite ice creams': ['MCC','chocolate']}

# %%
type(dict_cream)
# Out:
# dict

# %%
print(dict_cream)
# Out:
# {'name': 'Christopher Wijk', 'weekly intake': 5, 'favorite ice creams': ['MCC', 'chocolate']}

# %%
dict_cream.values()
# Out:
# dict_values(['Christopher Wijk', 5, ['MCC', 'chocolate']])

# %%
dict_cream.keys()
# Out:
# dict_keys(['name', 'weekly intake', 'favorite ice creams'])

# %%
dict_cream.items()
# Out:
# dict_items([('name', 'Christopher Wijk'), ('weekly intake', 5), ('favorite ice creams', ['MCC', 'chocolate'])])

# %%
dict_cream['name']
# Out:
# 'Christopher Wijk'

# %%
dict_cream['name'] = 'Christopher Wijk Karlsson'

print(dict_cream)
# Out:
# {'name': 'Christopher Wijk Karlsson', 'weekly intake': 5, 'favorite ice creams': ['MCC', 'chocolate']}

# %%
dict_cream.update({'name': 'Christopher Wijk Karlsson', 'weekly intake': 10, 'weight': 300})

print(dict_cream)
# Out:
# {'name': 'Christopher Wijk Karlsson', 'weekly intake': 10, 'favorite ice creams': ['MCC', 'chocolate'], 'weight': 300}

# %%
del dict_cream['weight']

print(dict_cream)
# Out:
# {'name': 'Christopher Wijk Karlsson', 'weekly intake': 10, 'favorite ice creams': ['MCC', 'chocolate']}

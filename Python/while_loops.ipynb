# %%
# to iterate over a block of code as long as the test condition is true.

# %%
# Difference between for and while loops is that for loop is going to iterate over the entire sequence regardless of a condition.
# While loop is ONLY going to iterate over that sequence as long as a specific condition is met.

# %%
number = 0
while number < 5:
    print(number)
    number = number + 1
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
number = 0
while number < 5:
    print(number)
    if number == 3:
        break
    number = number + 1
# Out:
# 0
# 1
# 2
# 3

# %%
number = 0
while number < 5:
    print(number)
    if number == 6:
        break
    number = number + 1
else:
    print('No longer < 5')
# Out:
# 0
# 1
# 2
# 3
# 4
# No longer < 5

# %%
number = 0
while number < 5:
    print(number)
    if number == 3:
        continue
    number = number + 1
else:
    print('No longer < 5')
